# %%
# import tensorflow as tf
import numpy as np
import getopt
import shutil
import pickle
import sys
import os
from pathlib import Path

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

import memory_operations as op

def llprint(message):
    sys.stdout.write(message)
    sys.stdout.flush()

def load(path):
    return pickle.load(open(path, 'rb'))

def onehot(index, size):
    vec = np.zeros(size, dtype=np.float32)
    index = int(index)
    vec[index] = 1.0
    return vec

def prepare_sample(sample, target_code, word_space_size):
    
    """
    prepares the input/output sequence of a sample story by encoding it
    into one-hot vectors and generates the necessary loss weights
    """
    
    input_vec = np.array(sample[0]['inputs'], dtype=np.float32)
    output_vec = np.array(sample[0]['inputs'], dtype=np.float32)
    
    seq_len = input_vec.shape[0]
    weights_vec = np.zeros(seq_len, dtype=np.float32)

    target_mask = (input_vec == target_code)
    output_vec[target_mask] = sample[0]['outputs']
    weights_vec[target_mask] = 1.0

    input_vec = np.array([onehot(code, word_space_size) for code in input_vec])
    output_vec = np.array([onehot(code, word_space_size) for code in output_vec])

    return (
        np.reshape(input_vec, (-1, word_space_size)),
        np.reshape(output_vec, (-1, word_space_size)),
        seq_len,
        np.reshape(weights_vec, (-1, 1))
    )

# task_dir = os.path.dirname(os.path.realpath(__file__))

#get the current path of our code
task_dir = Path().resolve()
llprint("Loading Data ... ")
lexicon_dict = load(os.path.join(task_dir, "data\\en-10k\\lexicon-dict.pkl"))
data = load(os.path.join(task_dir, "data\\en-10k\\train\\train.pkl"))
llprint("Done!\n")

# the model parameters

# memory size NxW
N = 128 #256
W = 32  #64 

# number of read heads
R = 2   #4    # memory parameters

X = 159   # input size
Y = 159   # output size

NN = 256  # controller's network output size

# setting up zeta
zeta_size = R*W + 3*W + 5*R + 3

# training parameters, number of iterations
iterations = 20000   #10000

# in case of using RMSProp
learning_rate = 0.001
momentum = 0.9


def network(step_input, state):
    
    """
    defines the recurrent neural network operation
    """
    
    global NN
    step_input = tf.expand_dims(step_input, 0)
    lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(NN)

    return lstm_cell(step_input, state)

# START: Computational Graph
graph = tf.Graph()


with graph.as_default():
    
    # optimizer
    # optimizer = tf.train.RMSPropOptimizer(learning_rate, momentum=momentum)
    optimizer = tf.train.AdamOptimizer()

    # placeholders
    input_data = tf.placeholder(tf.float32, [None, X])
    target_output = tf.placeholder(tf.float32, [None, Y])
    loss_weights = tf.placeholder(tf.float32, [None, 1])
    sequence_length = tf.placeholder(tf.int32)

    initial_nn_state = tf.nn.rnn_cell.BasicLSTMCell(NN).zero_state(1, tf.float32)

    empty_unpacked_inputs = tf.TensorArray(tf.float32, sequence_length)
    unpacked_inputs = empty_unpacked_inputs.unstack(input_data)
    outputs_container = tf.TensorArray(tf.float32, sequence_length)  # accumulates the step outputs
    t = tf.constant(0, dtype=tf.int32)

    def step_op(time, memory_state, controller_state, inputs, outputs):
        
        """
        defines the operation of one step of the sequence
        """
        global N, W, R

        step_input = inputs.read(time)
        M, u, p, L, wr, ww, r = memory_state

        with tf.variable_scope('controller'):

            std = lambda input_size: np.minimum(0.01, np.sqrt(2./ input_size))
            
            Xt = tf.concat(values=[step_input, tf.reshape(r, [-1])],axis=0,)
            #Xt = tf.concat(0, [step_input, tf.reshape(r, [-1])])

            nn_output, nn_state = network(Xt, controller_state)

            W_zeta = tf.get_variable('W_zeta', [NN, zeta_size], tf.float32, tf.truncated_normal_initializer(stddev=std(NN)))
            #W_zeta = tf.get_variable("W_zeta", [NN, zeta_size], tf.truncated_normal_initializer(stddev=std(NN)))
            
            #weight_init = tf.random_normal_initializer(stddev=(2.0/weight_shape[0])**0.5)
            #W = tf.get_variable("W", weight_shape, initializer=weight_init)

            W_y = tf.get_variable('W_y', [NN, Y], tf.float32, tf.truncated_normal_initializer(stddev=std(NN)))
            #W_y = tf.get_variable("W_y", [NN, Y], tf.truncated_normal_initializer(stddev=std(NN)))
            #W_y = tf.get_variable('W_y', [NN, Y], tf.float32, tf.truncated_normal_initializer(stddev=std(NN)))

            
            pre_output = tf.matmul(nn_output, W_y)
            zeta = tf.squeeze(tf.matmul(nn_output, W_zeta))
            kr, br, kw, bw, e, v, f, ga, gw, pi = op.parse_interface(zeta, N, W, R)
            
            # write head operations
            u_t = op.ut(u, f, wr, ww)

            #a_t = op.at(u_t, N)
            cw_t = op.C(M, kw, bw)
            a_t = op.at(u_t, N)
            ww_t = op.wwt(cw_t, a_t, gw, ga)
            M_t = op.Mt(M, ww_t, e, v)
            L_t = op.Lt(L, ww_t, p, N)
            p_t = op.pt(ww_t, p)

            # read heads operations
            cr_t = op.C(M_t, kr, br)
            wr_t = op.wrt(wr, L_t, cr_t, pi)
            r_t = op.rt(M_t, wr_t)

            W_r = tf.get_variable('W_r', [W*R, Y], tf.float32, tf.truncated_normal_initializer(stddev=std(W*R)))
            flat_rt = tf.reshape(r_t, [-1])
            final_output = pre_output + tf.matmul(tf.expand_dims(flat_rt, 0), W_r)
            updated_outputs = outputs.write(time, tf.squeeze(final_output))

            return time + 1, (M_t, u_t, p_t, L_t, wr_t, ww_t, r_t), nn_state, inputs, updated_outputs
    
    _, _, _, _, final_outputs = tf.while_loop(
        cond = lambda time, *_: time < sequence_length,
        body = step_op, loop_vars=(t, op.init_memory(N,W,R), initial_nn_state, unpacked_inputs, outputs_container),
        parallel_iterations=32,
        swap_memory=True
    )

    # pack the individual steps outputs into a single (sequence_length x Y) tensor
    packed_output = final_outputs.stack()
    loss = tf.reduce_mean(loss_weights*tf.nn.softmax_cross_entropy_with_logits(logits=packed_output, labels=target_output))
    gradients = optimizer.compute_gradients(loss)
    
    # w/o gradient clipping and w/ gradient clipping by value tf.clip by value in the range of 6 & 10
    # clipping the gradients by value to avoid explosion
#     for i, (grad, var) in enumerate(gradients):
#         if grad is not None:
#             gradients[i] = (tf.clip_by_value(grad, -6, 6), var)
#             # gradients[i] = (tf.clip_by_value(grad, -10, 10), var)
    apply_grads = optimizer.apply_gradients(gradients)
    # END: Computational Graph

#     # Reading command line arguments and adapting parameters
#     options,_ = getopt.getopt(sys.argv[1:], '', ['iterations='])
#     for opt in options:
#         iterations = int(opt[1])

    with tf.Session(graph=graph) as session:

        #session.run(tf.global_variables_initializer())
        session.run(tf.initializers.global_variables())

        last_100_losses = []
        print("")
        for i in range(iterations):

            llprint("\r iteration %d/%d" % (i, iterations))

            sample = np.random.choice(data, 1)
            input_seq, target_seq, seq_len, weights = prepare_sample(sample, lexicon_dict['-'], 159)

            loss_value,_, = session.run([loss, apply_grads], feed_dict={
                input_data: input_seq,
                target_output: target_seq,
                sequence_length: seq_len,
                loss_weights: weights
            })

            last_100_losses.append(loss_value)
            if i % 100 == 0:
                print("\n\tAvg. Cross-Entropy Loss: %0.6f" % (np.mean(last_100_losses)))
                last_100_losses = []

        model_path = os.path.join(task_dir, 'bAbI-model')
        
        if os.path.exists(model_path):
            shutil.rmtree(model_path)
        os.mkdir(model_path)
        
        tf.train.Saver().save(session, os.path.join(model_path, 'model.ckpt'))
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Loading Data ... Done!
# WARNING:tensorflow:From <ipython-input-1-eb1b665ee856>:117: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From <ipython-input-1-eb1b665ee856>:190: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:281: setdiff1d (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# This op will be removed after the deprecation date. Please switch to tf.sets.difference().
#
#  iteration 0/20000
# 	Avg. Cross-Entropy Loss: 0.266800
#  iteration 100/20000
# 	Avg. Cross-Entropy Loss: 0.169729
#  iteration 200/20000
# 	Avg. Cross-Entropy Loss: 0.146864
#  iteration 300/20000
# 	Avg. Cross-Entropy Loss: 0.145788
#  iteration 400/20000
# 	Avg. Cross-Entropy Loss: 0.109609
#  iteration 500/20000
# 	Avg. Cross-Entropy Loss: 0.103088
#  iteration 600/20000
# 	Avg. Cross-Entropy Loss: 0.078453
#  iteration 700/20000
# 	Avg. Cross-Entropy Loss: 0.073654
#  iteration 800/20000
# 	Avg. Cross-Entropy Loss: 0.056590
#  iteration 900/20000
# 	Avg. Cross-Entropy Loss: 0.054081
#  iteration 1000/20000
# 	Avg. Cross-Entropy Loss: 0.049291
#  iteration 1100/20000
# 	Avg. Cross-Entropy Loss: 0.041104
#  iteration 1200/20000
# 	Avg. Cross-Entropy Loss: 0.036220
#  iteration 1300/20000
# 	Avg. Cross-Entropy Loss: 0.035753
#  iteration 1400/20000
# 	Avg. Cross-Entropy Loss: 0.026743
#  iteration 1500/20000
# 	Avg. Cross-Entropy Loss: 0.029293
#  iteration 1600/20000
# 	Avg. Cross-Entropy Loss: 0.024628
#  iteration 1700/20000
# 	Avg. Cross-Entropy Loss: 0.026333
#  iteration 1800/20000
# 	Avg. Cross-Entropy Loss: 0.020011
#  iteration 1900/20000
# 	Avg. Cross-Entropy Loss: 0.019166
#  iteration 2000/20000
# 	Avg. Cross-Entropy Loss: 0.015538
#  iteration 2100/20000
# 	Avg. Cross-Entropy Loss: 0.015446
#  iteration 2200/20000
# 	Avg. Cross-Entropy Loss: 0.017223
#  iteration 2300/20000
# 	Avg. Cross-Entropy Loss: 0.015107
#  iteration 2400/20000
# 	Avg. Cross-Entropy Loss: 0.013790
#  iteration 2500/20000
# 	Avg. Cross-Entropy Loss: 0.013848
#  iteration 2600/20000
# 	Avg. Cross-Entropy Loss: 0.011364
#  iteration 2700/20000
# 	Avg. Cross-Entropy Loss: 0.011426
#  iteration 2800/20000
# 	Avg. Cross-Entropy Loss: 0.012079
#  iteration 2900/20000
# 	Avg. Cross-Entropy Loss: 0.011513
#  iteration 3000/20000
# 	Avg. Cross-Entropy Loss: 0.009621
#  iteration 3100/20000
# 	Avg. Cross-Entropy Loss: 0.007573
#  iteration 3200/20000
# 	Avg. Cross-Entropy Loss: 0.008095
#  iteration 3300/20000
# 	Avg. Cross-Entropy Loss: 0.008378
#  iteration 3400/20000
# 	Avg. Cross-Entropy Loss: 0.012366
#  iteration 3500/20000
# 	Avg. Cross-Entropy Loss: 0.007432
#  iteration 3600/20000
# 	Avg. Cross-Entropy Loss: 0.006766
#  iteration 3700/20000
# 	Avg. Cross-Entropy Loss: 0.006946
#  iteration 3800/20000
# 	Avg. Cross-Entropy Loss: 0.005381
#  iteration 3900/20000
# 	Avg. Cross-Entropy Loss: 0.006620
#  iteration 4000/20000
# 	Avg. Cross-Entropy Loss: 0.005760
#  iteration 4100/20000
# 	Avg. Cross-Entropy Loss: 0.004830
#  iteration 4200/20000
# 	Avg. Cross-Entropy Loss: 0.004470
#  iteration 4300/20000
# 	Avg. Cross-Entropy Loss: 0.004774
#  iteration 4400/20000
# 	Avg. Cross-Entropy Loss: 0.006495
#  iteration 4500/20000
# 	Avg. Cross-Entropy Loss: 0.007177
#  iteration 4600/20000
# 	Avg. Cross-Entropy Loss: 0.005758
#  iteration 4700/20000
# 	Avg. Cross-Entropy Loss: 0.004847
#  iteration 4800/20000
# 	Avg. Cross-Entropy Loss: 0.004799
#  iteration 4900/20000
# 	Avg. Cross-Entropy Loss: 0.003910
#  iteration 5000/20000
# 	Avg. Cross-Entropy Loss: 0.005883
#  iteration 5100/20000
# 	Avg. Cross-Entropy Loss: 0.004752
#  iteration 5200/20000
# 	Avg. Cross-Entropy Loss: 0.004712
#  iteration 5300/20000
# 	Avg. Cross-Entropy Loss: 0.005562
#  iteration 5400/20000
# 	Avg. Cross-Entropy Loss: 0.004114
#  iteration 5500/20000
# 	Avg. Cross-Entropy Loss: 0.003794
#  iteration 5600/20000
# 	Avg. Cross-Entropy Loss: 0.003999
#  iteration 5700/20000
# 	Avg. Cross-Entropy Loss: 0.004249
#  iteration 5800/20000
# 	Avg. Cross-Entropy Loss: 0.005150
#  iteration 5900/20000
# 	Avg. Cross-Entropy Loss: 0.004794
#  iteration 6000/20000
# 	Avg. Cross-Entropy Loss: 0.003606
#  iteration 6100/20000
# 	Avg. Cross-Entropy Loss: 0.003915
#  iteration 6200/20000
# 	Avg. Cross-Entropy Loss: 0.003836
#  iteration 6300/20000
# 	Avg. Cross-Entropy Loss: 0.003455
#  iteration 6400/20000
# 	Avg. Cross-Entropy Loss: 0.003796
#  iteration 6500/20000
# 	Avg. Cross-Entropy Loss: 0.002909
#  iteration 6600/20000
# 	Avg. Cross-Entropy Loss: 0.003371
#  iteration 6700/20000
# 	Avg. Cross-Entropy Loss: 0.003339
#  iteration 6800/20000
# 	Avg. Cross-Entropy Loss: 0.003250
#  iteration 6900/20000
# 	Avg. Cross-Entropy Loss: 0.003748
#  iteration 7000/20000
# 	Avg. Cross-Entropy Loss: 0.004043
#  iteration 7100/20000
# 	Avg. Cross-Entropy Loss: 0.004164
#  iteration 7200/20000
# 	Avg. Cross-Entropy Loss: 0.003207
#  iteration 7300/20000
# 	Avg. Cross-Entropy Loss: 0.003618
#  iteration 7400/20000
# 	Avg. Cross-Entropy Loss: 0.003258
#  iteration 7500/20000
# 	Avg. Cross-Entropy Loss: 0.003009
#  iteration 7600/20000
# 	Avg. Cross-Entropy Loss: 0.002680
#  iteration 7700/20000
# 	Avg. Cross-Entropy Loss: 0.003112
#  iteration 7800/20000
# 	Avg. Cross-Entropy Loss: 0.004719
#  iteration 7900/20000
# 	Avg. Cross-Entropy Loss: 0.004370
#  iteration 8000/20000
# 	Avg. Cross-Entropy Loss: 0.003569
#  iteration 8100/20000
# 	Avg. Cross-Entropy Loss: 0.002864
#  iteration 8200/20000
# 	Avg. Cross-Entropy Loss: 0.003210
#  iteration 8300/20000
# 	Avg. Cross-Entropy Loss: 0.002728
#  iteration 8400/20000
# 	Avg. Cross-Entropy Loss: 0.003721
#  iteration 8500/20000
# 	Avg. Cross-Entropy Loss: 0.003376
#  iteration 8600/20000
# 	Avg. Cross-Entropy Loss: 0.003434
#  iteration 8700/20000
# 	Avg. Cross-Entropy Loss: 0.002894
#  iteration 8800/20000
# 	Avg. Cross-Entropy Loss: 0.003201
#  iteration 8900/20000
# 	Avg. Cross-Entropy Loss: 0.003009
#  iteration 9000/20000
# 	Avg. Cross-Entropy Loss: 0.002953
#  iteration 9100/20000
# 	Avg. Cross-Entropy Loss: 0.003341
#  iteration 9200/20000
# 	Avg. Cross-Entropy Loss: 0.003455
#  iteration 9300/20000
# 	Avg. Cross-Entropy Loss: 0.002842
#  iteration 9400/20000
# 	Avg. Cross-Entropy Loss: 0.002839
#  iteration 9500/20000
# 	Avg. Cross-Entropy Loss: 0.002730
#  iteration 9600/20000
# 	Avg. Cross-Entropy Loss: 0.002966
#  iteration 9700/20000
# 	Avg. Cross-Entropy Loss: 0.002551
#  iteration 9800/20000
# 	Avg. Cross-Entropy Loss: 0.002829
#  iteration 9900/20000
# 	Avg. Cross-Entropy Loss: 0.002941
#  iteration 10000/20000
# 	Avg. Cross-Entropy Loss: 0.002789
#  iteration 10100/20000
# 	Avg. Cross-Entropy Loss: 0.002911
#  iteration 10200/20000
# 	Avg. Cross-Entropy Loss: 0.003071
#  iteration 10300/20000
# 	Avg. Cross-Entropy Loss: 0.002839
#  iteration 10400/20000
# 	Avg. Cross-Entropy Loss: 0.002488
#  iteration 10500/20000
# 	Avg. Cross-Entropy Loss: 0.002638
#  iteration 10600/20000
# 	Avg. Cross-Entropy Loss: 0.002598
#  iteration 10700/20000
# 	Avg. Cross-Entropy Loss: 0.002330
#  iteration 10800/20000
# 	Avg. Cross-Entropy Loss: 0.002524
#  iteration 10900/20000
# 	Avg. Cross-Entropy Loss: 0.002449
#  iteration 11000/20000
# 	Avg. Cross-Entropy Loss: 0.002364
#  iteration 11100/20000
# 	Avg. Cross-Entropy Loss: 0.003323
#  iteration 11200/20000
# 	Avg. Cross-Entropy Loss: 0.003441
#  iteration 11300/20000
# 	Avg. Cross-Entropy Loss: 0.003194
#  iteration 11400/20000
# 	Avg. Cross-Entropy Loss: 0.003035
#  iteration 11500/20000
# 	Avg. Cross-Entropy Loss: 0.002683
#  iteration 11600/20000
# 	Avg. Cross-Entropy Loss: 0.002561
#  iteration 11700/20000
# 	Avg. Cross-Entropy Loss: 0.002681
#  iteration 11800/20000
# 	Avg. Cross-Entropy Loss: 0.002369
#  iteration 11900/20000
# 	Avg. Cross-Entropy Loss: 0.002425
#  iteration 12000/20000
# 	Avg. Cross-Entropy Loss: 0.002563
#  iteration 12100/20000
# 	Avg. Cross-Entropy Loss: 0.002747
#  iteration 12200/20000
# 	Avg. Cross-Entropy Loss: 0.002465
#  iteration 12300/20000
# 	Avg. Cross-Entropy Loss: 0.002422
#  iteration 12400/20000
# 	Avg. Cross-Entropy Loss: 0.002476
#  iteration 12500/20000
# 	Avg. Cross-Entropy Loss: 0.002511
#  iteration 12600/20000
# 	Avg. Cross-Entropy Loss: 0.002574
#  iteration 12700/20000
# 	Avg. Cross-Entropy Loss: 0.002653
#  iteration 12800/20000
# 	Avg. Cross-Entropy Loss: 0.002520
#  iteration 12900/20000
# 	Avg. Cross-Entropy Loss: 0.002249
#  iteration 13000/20000
# 	Avg. Cross-Entropy Loss: 0.002274
#  iteration 13100/20000
# 	Avg. Cross-Entropy Loss: 0.002201
#  iteration 13200/20000
# 	Avg. Cross-Entropy Loss: 0.002386
#  iteration 13300/20000
# 	Avg. Cross-Entropy Loss: 0.002421
#  iteration 13400/20000
# 	Avg. Cross-Entropy Loss: 0.002267
#  iteration 13500/20000
# 	Avg. Cross-Entropy Loss: 0.002597
#  iteration 13600/20000
# 	Avg. Cross-Entropy Loss: 0.002291
#  iteration 13700/20000
# 	Avg. Cross-Entropy Loss: 0.002354
#  iteration 13800/20000
# 	Avg. Cross-Entropy Loss: 0.002384
#  iteration 13900/20000
# 	Avg. Cross-Entropy Loss: 0.002188
#  iteration 14000/20000
# 	Avg. Cross-Entropy Loss: 0.002368
#  iteration 14100/20000
# 	Avg. Cross-Entropy Loss: 0.002366
#  iteration 14200/20000
# 	Avg. Cross-Entropy Loss: 0.002456
#  iteration 14300/20000
# 	Avg. Cross-Entropy Loss: 0.002632
#  iteration 14400/20000
# 	Avg. Cross-Entropy Loss: 0.002329
#  iteration 14500/20000
# 	Avg. Cross-Entropy Loss: 0.002337
#  iteration 14600/20000
# 	Avg. Cross-Entropy Loss: 0.002234
#  iteration 14700/20000
# 	Avg. Cross-Entropy Loss: 0.002500
#  iteration 14800/20000
# 	Avg. Cross-Entropy Loss: 0.002355
#  iteration 14900/20000
# 	Avg. Cross-Entropy Loss: 0.002184
#  iteration 15000/20000
# 	Avg. Cross-Entropy Loss: 0.002361
#  iteration 15100/20000
# 	Avg. Cross-Entropy Loss: 0.002297
#  iteration 15200/20000
# 	Avg. Cross-Entropy Loss: 0.002282
#  iteration 15300/20000
# 	Avg. Cross-Entropy Loss: 0.002282
#  iteration 15400/20000
# 	Avg. Cross-Entropy Loss: 0.002020
#  iteration 15500/20000
# 	Avg. Cross-Entropy Loss: 0.003052
#  iteration 15600/20000
# 	Avg. Cross-Entropy Loss: 0.002151
#  iteration 15700/20000
# 	Avg. Cross-Entropy Loss: 0.002619
#  iteration 15800/20000
# 	Avg. Cross-Entropy Loss: 0.002209
#  iteration 15900/20000
# 	Avg. Cross-Entropy Loss: 0.002156
#  iteration 16000/20000
# 	Avg. Cross-Entropy Loss: 0.002434
#  iteration 16100/20000
# 	Avg. Cross-Entropy Loss: 0.002256
#  iteration 16200/20000
# 	Avg. Cross-Entropy Loss: 0.002313
#  iteration 16300/20000
# 	Avg. Cross-Entropy Loss: 0.002031
#  iteration 16400/20000
# 	Avg. Cross-Entropy Loss: 0.002454
#  iteration 16500/20000
# 	Avg. Cross-Entropy Loss: 0.002706
#  iteration 16600/20000
# 	Avg. Cross-Entropy Loss: 0.002202
#  iteration 16700/20000
# 	Avg. Cross-Entropy Loss: 0.002364
#  iteration 16800/20000
# 	Avg. Cross-Entropy Loss: 0.002103
#  iteration 16900/20000
# 	Avg. Cross-Entropy Loss: 0.002048
#  iteration 17000/20000
# 	Avg. Cross-Entropy Loss: 0.001925
#  iteration 17100/20000
# 	Avg. Cross-Entropy Loss: 0.002682
#  iteration 17200/20000
# 	Avg. Cross-Entropy Loss: 0.002320
#  iteration 17300/20000
# 	Avg. Cross-Entropy Loss: 0.002013
#  iteration 17400/20000
# 	Avg. Cross-Entropy Loss: 0.002020
#  iteration 17500/20000
# 	Avg. Cross-Entropy Loss: 0.002162
#  iteration 17600/20000
# 	Avg. Cross-Entropy Loss: 0.001972
#  iteration 17700/20000
# 	Avg. Cross-Entropy Loss: 0.001942
#  iteration 17800/20000
# 	Avg. Cross-Entropy Loss: 0.002036
#  iteration 17900/20000
# 	Avg. Cross-Entropy Loss: 0.002183
#  iteration 18000/20000
# 	Avg. Cross-Entropy Loss: 0.002113
#  iteration 18100/20000
# 	Avg. Cross-Entropy Loss: 0.002150
#  iteration 18200/20000
# 	Avg. Cross-Entropy Loss: 0.002300
#  iteration 18300/20000
# 	Avg. Cross-Entropy Loss: 0.002264
#  iteration 18400/20000
# 	Avg. Cross-Entropy Loss: 0.002151
#  iteration 18500/20000
# 	Avg. Cross-Entropy Loss: 0.002218
#  iteration 18600/20000
# 	Avg. Cross-Entropy Loss: 0.002001
#  iteration 18700/20000
# 	Avg. Cross-Entropy Loss: 0.001964
#  iteration 18800/20000
# 	Avg. Cross-Entropy Loss: 0.002387
#  iteration 18900/20000
# 	Avg. Cross-Entropy Loss: 0.002036
#  iteration 19000/20000
# 	Avg. Cross-Entropy Loss: 0.002197
#  iteration 19100/20000
# 	Avg. Cross-Entropy Loss: 0.002372
#  iteration 19200/20000
# 	Avg. Cross-Entropy Loss: 0.002251
#  iteration 19300/20000
# 	Avg. Cross-Entropy Loss: 0.002147
#  iteration 19400/20000
# 	Avg. Cross-Entropy Loss: 0.001905
#  iteration 19500/20000
# 	Avg. Cross-Entropy Loss: 0.001957
#  iteration 19600/20000
# 	Avg. Cross-Entropy Loss: 0.002267
#  iteration 19700/20000
# 	Avg. Cross-Entropy Loss: 0.002167
#  iteration 19800/20000
# 	Avg. Cross-Entropy Loss: 0.002049
#  iteration 19900/20000
# 	Avg. Cross-Entropy Loss: 0.001945
#  iteration 19999/20000
