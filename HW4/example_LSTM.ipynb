# %% [markdown]
# # Import

# %%
'''
A Recurrent Neural Network (LSTM) implementation example using TensorFlow
Next word prediction after n_input words learned from text file
A story is automatically generated if the predicted word is fed back as input
Based on Rowel Atienza's code
'''

from __future__ import print_function

import tensorflow as tf
from tensorflow.contrib import rnn

import numpy as np
import random
import collections

import time

# %% [markdown]
# # Record Elapsed time

# %%
def time_elapsed(t):

    if t<60:
        return str(t) + " second(s)"
    elif t<(60*60):
        return str(t/60) + " minute(s)"
    else:
        return str(t/(60*60)) + " hour(s)"

# %% [markdown]
# # Build Dataset

# %%
# read word data from files
def read_data(fname):
    
    with open(fname) as f:
        content = f.readlines()
    # strip useless indent    
    content = [x.strip() for x in content]
    content = [word for i in range(len(content)) for word in content[i].split()]
    content = np.array(content)
    return content


#module for building dictionary and reverse dictionary.
def build_dataset(words):
    #Return a list of the n most common elements and their counts from the most common to the least. 
    #If n is omitted or None, most_common() returns all elements in the counter.
    count = collections.Counter(words).most_common()
    dictionary = dict()
    for word, _ in count:
        #key of the dictionary is the word and take the index of frequencies as the corresponding value
        dictionary[word] = len(dictionary)
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reverse_dictionary

# %% [markdown]
# # Function for Building RNN Layers

# %%
def module_RNN(x, weights, biases):
    
    #weights and biases are dictionaries with a key as 'out' and content as a matrix or an array
    # reshape to [1, n_input]
    x = tf.reshape(x, [-1, n_input])

    # Generate a n_input-element sequence of inputs
    # (e.g. [A] [slave] [named] -> [9] [10] [37])
    x = tf.split(x,n_input,1)
    
    # basic RNN cell
    #rnn_cell = rnn.BasicRNNCell(n_hidden)

    # 1-layer LSTM with n_hidden units
    rnn_cell = rnn.BasicLSTMCell(n_hidden)
    
    # 2-layer LSTM, each layer has n_hidden units. And you can wrap more layers together by doing list comprehension.
    #rnn_cell = rnn.MultiRNNCell([rnn.BasicLSTMCell(n_hidden),rnn.BasicLSTMCell(n_hidden)])

    # 3-layer LSTM, each layer has n_hidden units. 
    # And you can wrap more layers together by doing list comprehension.
    #rnn_cell = rnn.MultiRNNCell([rnn.BasicLSTMCell(n_hidden),rnn.BasicLSTMCell(n_hidden),rnn.BasicLSTMCell(n_hidden)])

    # generate prediction
    # creates a recurrent neural network specified by RNNCell cell
    outputs, states = rnn.static_rnn(rnn_cell, x, dtype=tf.float32)

    # there are n_input outputs but
    # we only want the last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %% [markdown]
# # Parameters and Load Data

# %%
# Parameters
learning_rate = 0.001

#training_iters = 100000
training_iters = 5000

display_step = 10
# number of words to be put into the network
n_input = 3

# number of words prediction after n_input
n_output = 5


# number of units in RNN cell
#n_hidden = 60
n_hidden = 4


# Text file containing words for training
training_file = 'simpleStory1.txt'
#training_file = 'simpleStory2.txt'
#training_file = 'androcles.txt'

training_data = read_data(training_file)
print("Loaded training data...")

dictionary, reverse_dictionary = build_dataset(training_data)
vocab_size = len(dictionary)
# Out:
# Loaded training data...

# %% [markdown]
# # Main Function

# %%
# TensorFlow Graph input
x = tf.placeholder("float", [None, n_input, 1])
y = tf.placeholder("float", [None, vocab_size])


# Logs_path
logs_path = 'C:/Users/Ali/logs/RNNs'
writer  = tf.summary.FileWriter(logs_path)

# RNN output node weights and biases
weights = {'out': tf.Variable(tf.random_normal([n_hidden, vocab_size]))}
biases  = {'out': tf.Variable(tf.random_normal([vocab_size]))}

# get the prediction in the probability form from the output of wraped RNN layers
pred = module_RNN(x, weights, biases)

# Loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

# Model evaluation
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

start_time = time.time()

# Launch the graph
with tf.Session() as session:
    session.run(init)
    step = 0
    offset = random.randint(0, n_input+1)
    end_offset = n_input + 1
    acc_total = 0
    loss_total = 0

    writer.add_graph(session.graph)

    while step < training_iters:

        # Generate a mini-batch
        # Add some randomness on selection process

        if offset > (len(training_data)-end_offset):
            offset = random.randint(0, n_input+1)
            
        #select size of n_input data from the training set and reshape them.
        symbols_in_keys = [ [dictionary[ str(training_data[i])]] for i in range(offset, offset+n_input) ]
        symbols_in_keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])
        
        #set up the one-hot-encoding of the labels and reshape them
        symbols_out_onehot = np.zeros([vocab_size], dtype=float)
        symbols_out_onehot[dictionary[str(training_data[offset+n_input])]] = 1.0
        symbols_out_onehot = np.reshape(symbols_out_onehot,[1,-1])
        
        # run optimizer,accuracy,cost and pred tensors and get the results
        _, acc, loss, onehot_pred = session.run([optimizer, accuracy, cost, pred], feed_dict={x: symbols_in_keys, y: symbols_out_onehot})

        loss_total += loss
        acc_total += acc
        
        #display the trend of loss and accuracy
        if (step+1) % display_step == 0:
            print("Iter = " + str(step+1) + ", average loss= " + \
                  "{:0.6f}".format(loss_total/display_step) + ", average accuracy= " + \
                  "{:0.2f}%".format(100*acc_total/display_step))
            #reset
            acc_total = 0
            loss_total = 0
            
            #have a brief view of the relationship of input, real value and prediction result
            symbols_in = [training_data[i] for i in range(offset, offset + n_input)]
            symbols_out = training_data[offset + n_input]
            symbols_out_pred = reverse_dictionary[int(tf.argmax(onehot_pred, 1).eval())]
            
            print("%s - [%s] vs [%s]" % (symbols_in, symbols_out, symbols_out_pred))
        step += 1
        offset += (n_input+1)
    print("Optimization Finished!")
    
    t_elapsed = time.time() - start_time
    print("Elapsed time: ", time_elapsed(t_elapsed))
    
    #Take a simple experiment using customized input
    while True:
        
        prompt = "insert %s words: " % n_input
        sentence = input(prompt)
        sentence = sentence.strip()
        words = sentence.split(' ')
        
        if len(words) != n_input:
            continue
        try:
            symbols_in_keys = [dictionary[str(words[i])] for i in range(len(words))]
            
            # how many words
            
            for i in range(n_output):
                keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])
                onehot_pred = session.run(pred, feed_dict={x: keys})
                onehot_pred_index = int(tf.argmax(onehot_pred, 1).eval())
                sentence = "%s %s" % (sentence, reverse_dictionary[onehot_pred_index])
                symbols_in_keys = symbols_in_keys[1:]
                symbols_in_keys.append(onehot_pred_index)
                
            print(sentence)
        except:
            print("cannot be found in dictionary")
# Out:
# WARNING:tensorflow:From <ipython-input-4-2299c533166d>:15: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-4-2299c533166d>:26: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\Ali\.conda\envs\tensorflow_env\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From C:\Users\Ali\.conda\envs\tensorflow_env\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From <ipython-input-6-62ae4f32eab6>:18: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From C:\Users\Ali\.conda\envs\tensorflow_env\lib\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Iter = 10, average loss= 2.661386, average accuracy= 10.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [Steve]
# Iter = 20, average loss= 3.029405, average accuracy= 20.00%
# ['had', 'breakfast', 'with'] - [David] vs [Steve]
# Iter = 30, average loss= 2.746608, average accuracy= 10.00%
# ['Steve', '.', 'Steve'] - [had] vs [Steve]
# Iter = 40, average loss= 2.571114, average accuracy= 10.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [Steve]
# Iter = 50, average loss= 2.550688, average accuracy= 0.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [Steve]
# Iter = 60, average loss= 2.726457, average accuracy= 10.00%
# ['dinner', 'with', 'Steve'] - [.] vs [Steve]
# Iter = 70, average loss= 2.492294, average accuracy= 0.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [Steve]
# Iter = 80, average loss= 2.221428, average accuracy= 0.00%
# ['breakfast', 'with', 'David'] - [.] vs [Steve]
# Iter = 90, average loss= 2.641903, average accuracy= 10.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [Steve]
# Iter = 100, average loss= 2.598910, average accuracy= 10.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [Steve]
# Iter = 110, average loss= 2.387747, average accuracy= 10.00%
# ['had', 'breakfast', 'with'] - [David] vs [Steve]
# Iter = 120, average loss= 2.643433, average accuracy= 20.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [Steve]
# Iter = 130, average loss= 2.260449, average accuracy= 0.00%
# ['dinner', 'with', 'Steve'] - [.] vs [Steve]
# Iter = 140, average loss= 2.762028, average accuracy= 20.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [Steve]
# Iter = 150, average loss= 2.024322, average accuracy= 0.00%
# ['breakfast', 'with', 'David'] - [.] vs [Steve]
# Iter = 160, average loss= 2.200971, average accuracy= 0.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [Steve]
# Iter = 170, average loss= 2.633128, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [Steve]
# Iter = 180, average loss= 2.149768, average accuracy= 0.00%
# ['dinner', 'with', 'Steve'] - [.] vs [Steve]
# Iter = 190, average loss= 2.492186, average accuracy= 20.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [Steve]
# Iter = 200, average loss= 2.291477, average accuracy= 0.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [Steve]
# Iter = 210, average loss= 2.462520, average accuracy= 20.00%
# ['had', 'breakfast', 'with'] - [David] vs [Steve]
# Iter = 220, average loss= 2.060438, average accuracy= 0.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [Steve]
# Iter = 230, average loss= 2.277965, average accuracy= 10.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [with]
# Iter = 240, average loss= 2.313395, average accuracy= 10.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Steve]
# Iter = 250, average loss= 2.444516, average accuracy= 30.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 260, average loss= 2.508591, average accuracy= 10.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [with]
# Iter = 270, average loss= 2.063287, average accuracy= 10.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [Steve]
# Iter = 280, average loss= 2.406073, average accuracy= 10.00%
# ['dinner', 'with', 'Steve'] - [.] vs [Steve]
# Iter = 290, average loss= 2.210721, average accuracy= 10.00%
# ['dinner', 'with', 'Steve'] - [.] vs [Steve]
# Iter = 300, average loss= 2.293817, average accuracy= 10.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Steve]
# Iter = 310, average loss= 2.256753, average accuracy= 20.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [Steve]
# Iter = 320, average loss= 2.703726, average accuracy= 30.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [Steve]
# Iter = 330, average loss= 1.761994, average accuracy= 0.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [Steve]
# Iter = 340, average loss= 1.916402, average accuracy= 20.00%
# ['breakfast', 'with', 'David'] - [.] vs [Steve]
# Iter = 350, average loss= 1.905991, average accuracy= 10.00%
# ['breakfast', 'with', 'David'] - [.] vs [Steve]
# Iter = 360, average loss= 2.143179, average accuracy= 30.00%
# ['breakfast', 'with', 'David'] - [.] vs [Steve]
# Iter = 370, average loss= 2.132643, average accuracy= 30.00%
# ['breakfast', 'with', 'David'] - [.] vs [Steve]
# Iter = 380, average loss= 2.200821, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 390, average loss= 2.460159, average accuracy= 20.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 400, average loss= 2.560018, average accuracy= 20.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 410, average loss= 2.409771, average accuracy= 20.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 420, average loss= 2.163356, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 430, average loss= 2.070938, average accuracy= 30.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 440, average loss= 2.056285, average accuracy= 30.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 450, average loss= 1.806443, average accuracy= 30.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [with]
# Iter = 460, average loss= 2.208298, average accuracy= 20.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 470, average loss= 2.051586, average accuracy= 20.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 480, average loss= 2.106856, average accuracy= 20.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [with]
# Iter = 490, average loss= 1.923689, average accuracy= 30.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 500, average loss= 1.761652, average accuracy= 30.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [with]
# Iter = 510, average loss= 2.225854, average accuracy= 10.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [with]
# Iter = 520, average loss= 1.706251, average accuracy= 40.00%
# ['Steve', '.', 'Steve'] - [had] vs [with]
# Iter = 530, average loss= 2.574475, average accuracy= 0.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 540, average loss= 2.252307, average accuracy= 20.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 550, average loss= 1.773868, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 560, average loss= 1.955596, average accuracy= 30.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 570, average loss= 1.985639, average accuracy= 20.00%
# ['Steve', '.', 'Steve'] - [had] vs [with]
# Iter = 580, average loss= 1.904802, average accuracy= 20.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 590, average loss= 1.651417, average accuracy= 40.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 600, average loss= 2.599676, average accuracy= 0.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 610, average loss= 1.924888, average accuracy= 30.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 620, average loss= 1.955362, average accuracy= 20.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 630, average loss= 2.348847, average accuracy= 10.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [with]
# Iter = 640, average loss= 1.679678, average accuracy= 40.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 650, average loss= 2.393001, average accuracy= 0.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [with]
# Iter = 660, average loss= 1.648762, average accuracy= 30.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [with]
# Iter = 670, average loss= 1.875926, average accuracy= 30.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 680, average loss= 1.813057, average accuracy= 30.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 690, average loss= 2.012819, average accuracy= 10.00%
# ['breakfast', 'with', 'David'] - [.] vs [with]
# Iter = 700, average loss= 1.578828, average accuracy= 40.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 710, average loss= 1.956154, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 720, average loss= 1.736931, average accuracy= 40.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [.]
# Iter = 730, average loss= 1.803130, average accuracy= 20.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 740, average loss= 1.657171, average accuracy= 30.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 750, average loss= 1.833475, average accuracy= 30.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 760, average loss= 2.242995, average accuracy= 10.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 770, average loss= 1.800429, average accuracy= 30.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 780, average loss= 1.816473, average accuracy= 30.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [.]
# Iter = 790, average loss= 1.969226, average accuracy= 20.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [with]
# Iter = 800, average loss= 2.194548, average accuracy= 10.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 810, average loss= 1.953041, average accuracy= 20.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 820, average loss= 2.290354, average accuracy= 10.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [.]
# Iter = 830, average loss= 2.096917, average accuracy= 10.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 840, average loss= 2.114493, average accuracy= 10.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 850, average loss= 1.620931, average accuracy= 40.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 860, average loss= 1.509316, average accuracy= 30.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 870, average loss= 2.064894, average accuracy= 20.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 880, average loss= 1.996212, average accuracy= 20.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 890, average loss= 2.046167, average accuracy= 10.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 900, average loss= 1.758188, average accuracy= 30.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 910, average loss= 1.585938, average accuracy= 30.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 920, average loss= 1.712967, average accuracy= 30.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 930, average loss= 2.160751, average accuracy= 10.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 940, average loss= 1.622051, average accuracy= 20.00%
# ['breakfast', 'with', 'David'] - [.] vs [with]
# Iter = 950, average loss= 2.102287, average accuracy= 20.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 960, average loss= 2.143581, average accuracy= 10.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 970, average loss= 1.776898, average accuracy= 20.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [with]
# Iter = 980, average loss= 1.422915, average accuracy= 50.00%
# ['Steve', '.', 'Steve'] - [had] vs [with]
# Iter = 990, average loss= 1.770674, average accuracy= 30.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1000, average loss= 1.470748, average accuracy= 50.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1010, average loss= 1.774256, average accuracy= 20.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 1020, average loss= 1.388682, average accuracy= 50.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 1030, average loss= 1.719275, average accuracy= 30.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 1040, average loss= 1.912594, average accuracy= 20.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 1050, average loss= 2.123483, average accuracy= 20.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [.]
# Iter = 1060, average loss= 1.737785, average accuracy= 30.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 1070, average loss= 1.772643, average accuracy= 20.00%
# ['Steve', '.', 'Steve'] - [had] vs [with]
# Iter = 1080, average loss= 1.896534, average accuracy= 30.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1090, average loss= 2.471954, average accuracy= 0.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [.]
# Iter = 1100, average loss= 1.852667, average accuracy= 20.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [with]
# Iter = 1110, average loss= 1.187873, average accuracy= 50.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1120, average loss= 2.083324, average accuracy= 10.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 1130, average loss= 1.766864, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1140, average loss= 1.926913, average accuracy= 20.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 1150, average loss= 1.737648, average accuracy= 30.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 1160, average loss= 1.750684, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1170, average loss= 1.644157, average accuracy= 30.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [with]
# Iter = 1180, average loss= 1.804527, average accuracy= 30.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1190, average loss= 1.897967, average accuracy= 20.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 1200, average loss= 1.732057, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1210, average loss= 2.037435, average accuracy= 10.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1220, average loss= 1.912477, average accuracy= 20.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1230, average loss= 2.047611, average accuracy= 10.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1240, average loss= 1.624539, average accuracy= 30.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 1250, average loss= 2.086799, average accuracy= 10.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 1260, average loss= 2.228773, average accuracy= 0.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1270, average loss= 1.565504, average accuracy= 40.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 1280, average loss= 1.322728, average accuracy= 30.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1290, average loss= 1.124444, average accuracy= 50.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [with]
# Iter = 1300, average loss= 1.741308, average accuracy= 30.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1310, average loss= 1.914174, average accuracy= 10.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 1320, average loss= 1.604614, average accuracy= 30.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 1330, average loss= 1.678707, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1340, average loss= 1.131679, average accuracy= 50.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 1350, average loss= 1.643865, average accuracy= 30.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 1360, average loss= 1.542734, average accuracy= 30.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1370, average loss= 1.535492, average accuracy= 30.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 1380, average loss= 1.681758, average accuracy= 30.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 1390, average loss= 1.526608, average accuracy= 30.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1400, average loss= 1.283962, average accuracy= 60.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1410, average loss= 1.713769, average accuracy= 40.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [.]
# Iter = 1420, average loss= 1.693748, average accuracy= 30.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 1430, average loss= 1.235799, average accuracy= 70.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 1440, average loss= 1.525982, average accuracy= 30.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1450, average loss= 1.337168, average accuracy= 50.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [.]
# Iter = 1460, average loss= 1.759434, average accuracy= 20.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 1470, average loss= 1.168724, average accuracy= 50.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 1480, average loss= 1.595197, average accuracy= 20.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1490, average loss= 1.097615, average accuracy= 80.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 1500, average loss= 1.331238, average accuracy= 50.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 1510, average loss= 2.332646, average accuracy= 0.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1520, average loss= 1.507725, average accuracy= 40.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1530, average loss= 1.738695, average accuracy= 20.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 1540, average loss= 1.190524, average accuracy= 40.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1550, average loss= 2.173658, average accuracy= 10.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 1560, average loss= 1.426693, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 1570, average loss= 2.252116, average accuracy= 0.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 1580, average loss= 1.248530, average accuracy= 40.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 1590, average loss= 1.352426, average accuracy= 40.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 1600, average loss= 1.556185, average accuracy= 20.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 1610, average loss= 1.319566, average accuracy= 60.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [.]
# Iter = 1620, average loss= 1.835738, average accuracy= 30.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 1630, average loss= 2.140611, average accuracy= 0.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 1640, average loss= 1.184436, average accuracy= 40.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 1650, average loss= 1.446908, average accuracy= 30.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 1660, average loss= 1.421097, average accuracy= 30.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 1670, average loss= 1.113035, average accuracy= 50.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1680, average loss= 0.922687, average accuracy= 70.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 1690, average loss= 1.777050, average accuracy= 20.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 1700, average loss= 1.441517, average accuracy= 40.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 1710, average loss= 1.040840, average accuracy= 40.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1720, average loss= 1.008021, average accuracy= 40.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1730, average loss= 1.421200, average accuracy= 40.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1740, average loss= 1.683590, average accuracy= 20.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 1750, average loss= 1.108403, average accuracy= 50.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 1760, average loss= 1.299326, average accuracy= 40.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 1770, average loss= 1.983224, average accuracy= 20.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 1780, average loss= 0.977588, average accuracy= 50.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1790, average loss= 1.436327, average accuracy= 30.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 1800, average loss= 0.938321, average accuracy= 60.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1810, average loss= 1.709500, average accuracy= 30.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 1820, average loss= 1.746619, average accuracy= 20.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1830, average loss= 1.774810, average accuracy= 30.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1840, average loss= 1.199282, average accuracy= 50.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 1850, average loss= 1.540092, average accuracy= 30.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1860, average loss= 1.315535, average accuracy= 30.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [.]
# Iter = 1870, average loss= 1.011591, average accuracy= 60.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1880, average loss= 1.689459, average accuracy= 30.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1890, average loss= 1.311727, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 1900, average loss= 2.194685, average accuracy= 10.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 1910, average loss= 1.171190, average accuracy= 60.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1920, average loss= 1.669667, average accuracy= 40.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 1930, average loss= 1.239986, average accuracy= 50.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 1940, average loss= 1.687859, average accuracy= 20.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 1950, average loss= 1.276267, average accuracy= 40.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 1960, average loss= 0.870293, average accuracy= 80.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 1970, average loss= 1.947852, average accuracy= 30.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 1980, average loss= 1.603740, average accuracy= 40.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 1990, average loss= 1.519035, average accuracy= 20.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 2000, average loss= 1.460920, average accuracy= 40.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 2010, average loss= 1.232761, average accuracy= 40.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2020, average loss= 1.330779, average accuracy= 70.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 2030, average loss= 1.068394, average accuracy= 70.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 2040, average loss= 1.225655, average accuracy= 60.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2050, average loss= 0.942768, average accuracy= 80.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2060, average loss= 1.642674, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 2070, average loss= 1.027948, average accuracy= 60.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 2080, average loss= 0.856306, average accuracy= 90.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 2090, average loss= 1.589296, average accuracy= 40.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 2100, average loss= 1.432657, average accuracy= 60.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 2110, average loss= 1.051548, average accuracy= 70.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 2120, average loss= 1.518463, average accuracy= 30.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 2130, average loss= 1.483055, average accuracy= 40.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 2140, average loss= 1.814812, average accuracy= 20.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2150, average loss= 1.080706, average accuracy= 70.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 2160, average loss= 1.348311, average accuracy= 50.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 2170, average loss= 1.027411, average accuracy= 70.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 2180, average loss= 1.630370, average accuracy= 50.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 2190, average loss= 1.868875, average accuracy= 30.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 2200, average loss= 1.580302, average accuracy= 30.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 2210, average loss= 1.330756, average accuracy= 50.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 2220, average loss= 1.712058, average accuracy= 50.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 2230, average loss= 0.920424, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2240, average loss= 1.273204, average accuracy= 70.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 2250, average loss= 1.273781, average accuracy= 70.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 2260, average loss= 0.879632, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2270, average loss= 1.243387, average accuracy= 60.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2280, average loss= 1.236588, average accuracy= 60.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2290, average loss= 0.786995, average accuracy= 80.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [.]
# Iter = 2300, average loss= 1.758764, average accuracy= 30.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 2310, average loss= 1.566204, average accuracy= 50.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 2320, average loss= 1.347494, average accuracy= 60.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2330, average loss= 1.551125, average accuracy= 60.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 2340, average loss= 1.671390, average accuracy= 50.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 2350, average loss= 1.707351, average accuracy= 40.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 2360, average loss= 1.535930, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 2370, average loss= 0.967224, average accuracy= 90.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 2380, average loss= 1.678941, average accuracy= 40.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 2390, average loss= 0.823007, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2400, average loss= 1.102279, average accuracy= 80.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 2410, average loss= 1.479864, average accuracy= 60.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 2420, average loss= 1.747778, average accuracy= 20.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 2430, average loss= 1.174730, average accuracy= 80.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 2440, average loss= 1.770439, average accuracy= 40.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 2450, average loss= 1.181216, average accuracy= 80.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 2460, average loss= 1.192938, average accuracy= 70.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 2470, average loss= 0.841267, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 2480, average loss= 1.015385, average accuracy= 90.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 2490, average loss= 1.671540, average accuracy= 50.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2500, average loss= 1.285007, average accuracy= 70.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 2510, average loss= 1.126282, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2520, average loss= 1.137275, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2530, average loss= 0.900585, average accuracy= 90.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 2540, average loss= 1.039539, average accuracy= 80.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2550, average loss= 1.310377, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2560, average loss= 1.340974, average accuracy= 50.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 2570, average loss= 0.885357, average accuracy= 90.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 2580, average loss= 1.246362, average accuracy= 60.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 2590, average loss= 1.519811, average accuracy= 50.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 2600, average loss= 1.177282, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2610, average loss= 1.410158, average accuracy= 60.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 2620, average loss= 1.382973, average accuracy= 50.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 2630, average loss= 1.295496, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2640, average loss= 1.432057, average accuracy= 50.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 2650, average loss= 0.939823, average accuracy= 90.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2660, average loss= 1.170120, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2670, average loss= 0.719995, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 2680, average loss= 0.717593, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 2690, average loss= 1.149849, average accuracy= 70.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 2700, average loss= 0.696303, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2710, average loss= 1.415110, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 2720, average loss= 2.015245, average accuracy= 30.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 2730, average loss= 1.253442, average accuracy= 70.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 2740, average loss= 1.077236, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2750, average loss= 1.254281, average accuracy= 60.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [.]
# Iter = 2760, average loss= 1.445383, average accuracy= 50.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 2770, average loss= 1.066866, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2780, average loss= 1.617960, average accuracy= 40.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 2790, average loss= 0.766090, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 2800, average loss= 1.248407, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 2810, average loss= 0.634503, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 2820, average loss= 0.750314, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 2830, average loss= 0.871940, average accuracy= 90.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 2840, average loss= 1.626709, average accuracy= 40.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 2850, average loss= 1.108471, average accuracy= 80.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 2860, average loss= 1.039265, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 2870, average loss= 1.410494, average accuracy= 40.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 2880, average loss= 0.740894, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 2890, average loss= 1.238757, average accuracy= 70.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 2900, average loss= 1.270091, average accuracy= 50.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 2910, average loss= 1.570458, average accuracy= 50.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 2920, average loss= 1.537490, average accuracy= 50.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 2930, average loss= 0.598718, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 2940, average loss= 0.664638, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 2950, average loss= 1.222250, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 2960, average loss= 1.165949, average accuracy= 70.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 2970, average loss= 1.958579, average accuracy= 10.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 2980, average loss= 1.342985, average accuracy= 60.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 2990, average loss= 0.955582, average accuracy= 80.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3000, average loss= 1.213358, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3010, average loss= 1.030441, average accuracy= 70.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 3020, average loss= 1.446411, average accuracy= 50.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 3030, average loss= 1.288748, average accuracy= 60.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3040, average loss= 0.654661, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3050, average loss= 0.708908, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3060, average loss= 1.138654, average accuracy= 70.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 3070, average loss= 1.069995, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3080, average loss= 0.637402, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3090, average loss= 1.201359, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3100, average loss= 0.566855, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3110, average loss= 1.920852, average accuracy= 20.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 3120, average loss= 1.039433, average accuracy= 70.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 3130, average loss= 0.890024, average accuracy= 90.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 3140, average loss= 1.558353, average accuracy= 40.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 3150, average loss= 1.198320, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3160, average loss= 0.755775, average accuracy= 90.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 3170, average loss= 0.987990, average accuracy= 80.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 3180, average loss= 1.249911, average accuracy= 60.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 3190, average loss= 0.984423, average accuracy= 80.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3200, average loss= 0.990279, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3210, average loss= 1.354718, average accuracy= 40.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 3220, average loss= 0.602767, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3230, average loss= 1.047483, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3240, average loss= 1.181157, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3250, average loss= 1.700545, average accuracy= 40.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 3260, average loss= 1.243421, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3270, average loss= 1.779524, average accuracy= 30.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [had]
# Iter = 3280, average loss= 0.860154, average accuracy= 80.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3290, average loss= 0.976142, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3300, average loss= 0.733308, average accuracy= 90.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 3310, average loss= 1.109318, average accuracy= 70.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 3320, average loss= 1.516449, average accuracy= 50.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3330, average loss= 1.028909, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3340, average loss= 0.539468, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3350, average loss= 0.660181, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 3360, average loss= 0.719784, average accuracy= 90.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 3370, average loss= 0.951630, average accuracy= 80.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 3380, average loss= 1.153462, average accuracy= 70.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 3390, average loss= 0.584741, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 3400, average loss= 1.161581, average accuracy= 60.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 3410, average loss= 0.948494, average accuracy= 80.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 3420, average loss= 1.204445, average accuracy= 50.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 3430, average loss= 1.145479, average accuracy= 60.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3440, average loss= 0.564249, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 3450, average loss= 1.156989, average accuracy= 70.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 3460, average loss= 1.523685, average accuracy= 40.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 3470, average loss= 0.876196, average accuracy= 80.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 3480, average loss= 0.693871, average accuracy= 90.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 3490, average loss= 0.612293, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 3500, average loss= 1.725912, average accuracy= 40.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3510, average loss= 1.141501, average accuracy= 70.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 3520, average loss= 1.000802, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3530, average loss= 1.138208, average accuracy= 70.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 3540, average loss= 0.988985, average accuracy= 70.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 3550, average loss= 0.931418, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3560, average loss= 1.286026, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 3570, average loss= 0.780137, average accuracy= 90.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 3580, average loss= 0.980653, average accuracy= 70.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 3590, average loss= 1.569614, average accuracy= 40.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 3600, average loss= 1.489314, average accuracy= 40.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 3610, average loss= 0.792651, average accuracy= 80.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 3620, average loss= 0.975861, average accuracy= 70.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 3630, average loss= 1.301532, average accuracy= 60.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3640, average loss= 0.542816, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 3650, average loss= 1.178444, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3660, average loss= 0.464449, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3670, average loss= 1.058637, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3680, average loss= 0.905024, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3690, average loss= 1.340834, average accuracy= 40.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 3700, average loss= 1.470273, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 3710, average loss= 0.817807, average accuracy= 90.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 3720, average loss= 1.467724, average accuracy= 40.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 3730, average loss= 1.599845, average accuracy= 40.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 3740, average loss= 1.167168, average accuracy= 60.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 3750, average loss= 1.430840, average accuracy= 50.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3760, average loss= 0.686931, average accuracy= 90.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 3770, average loss= 1.655688, average accuracy= 20.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3780, average loss= 0.549102, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 3790, average loss= 0.525845, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3800, average loss= 0.669918, average accuracy= 90.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 3810, average loss= 1.248422, average accuracy= 50.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 3820, average loss= 0.721827, average accuracy= 90.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 3830, average loss= 0.814250, average accuracy= 80.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3840, average loss= 1.821340, average accuracy= 20.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 3850, average loss= 1.248534, average accuracy= 60.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3860, average loss= 1.502311, average accuracy= 20.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 3870, average loss= 1.009261, average accuracy= 60.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 3880, average loss= 1.054859, average accuracy= 60.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [had]
# Iter = 3890, average loss= 0.685867, average accuracy= 80.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3900, average loss= 0.578317, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 3910, average loss= 0.910204, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3920, average loss= 0.434011, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3930, average loss= 1.078316, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3940, average loss= 0.481369, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3950, average loss= 0.535543, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3960, average loss= 1.026429, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3970, average loss= 1.225858, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 3980, average loss= 1.070106, average accuracy= 60.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3990, average loss= 1.078658, average accuracy= 70.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 4000, average loss= 0.892474, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4010, average loss= 1.380661, average accuracy= 40.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 4020, average loss= 0.887493, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4030, average loss= 0.671442, average accuracy= 90.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [had]
# Iter = 4040, average loss= 1.236298, average accuracy= 50.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4050, average loss= 0.655494, average accuracy= 80.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 4060, average loss= 0.702729, average accuracy= 90.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4070, average loss= 0.468418, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4080, average loss= 0.885865, average accuracy= 70.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 4090, average loss= 1.250208, average accuracy= 40.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 4100, average loss= 1.061644, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4110, average loss= 1.580168, average accuracy= 30.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 4120, average loss= 1.766028, average accuracy= 30.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 4130, average loss= 1.420046, average accuracy= 40.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 4140, average loss= 0.801083, average accuracy= 80.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 4150, average loss= 1.237228, average accuracy= 50.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 4160, average loss= 0.878978, average accuracy= 70.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 4170, average loss= 1.271231, average accuracy= 50.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 4180, average loss= 1.141655, average accuracy= 60.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 4190, average loss= 1.106164, average accuracy= 50.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 4200, average loss= 1.313313, average accuracy= 50.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [had]
# Iter = 4210, average loss= 1.017499, average accuracy= 50.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4220, average loss= 0.544230, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 4230, average loss= 0.513254, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4240, average loss= 0.498941, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 4250, average loss= 1.029965, average accuracy= 70.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 4260, average loss= 0.496589, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4270, average loss= 0.563987, average accuracy= 90.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [had]
# Iter = 4280, average loss= 0.724187, average accuracy= 80.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 4290, average loss= 0.799457, average accuracy= 70.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 4300, average loss= 0.538430, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 4310, average loss= 1.056098, average accuracy= 70.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 4320, average loss= 1.757101, average accuracy= 30.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [had]
# Iter = 4330, average loss= 1.183886, average accuracy= 50.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4340, average loss= 0.432772, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 4350, average loss= 1.083903, average accuracy= 50.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 4360, average loss= 1.312403, average accuracy= 50.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [had]
# Iter = 4370, average loss= 0.646451, average accuracy= 80.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 4380, average loss= 0.832596, average accuracy= 70.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 4390, average loss= 0.459591, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4400, average loss= 1.314421, average accuracy= 40.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4410, average loss= 1.308650, average accuracy= 40.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 4420, average loss= 0.992340, average accuracy= 70.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 4430, average loss= 1.336640, average accuracy= 40.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4440, average loss= 1.328502, average accuracy= 40.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 4450, average loss= 0.760513, average accuracy= 70.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 4460, average loss= 1.340905, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 4470, average loss= 0.972531, average accuracy= 60.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 4480, average loss= 1.159093, average accuracy= 40.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 4490, average loss= 0.457600, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4500, average loss= 0.932292, average accuracy= 70.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 4510, average loss= 0.394863, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4520, average loss= 1.528455, average accuracy= 40.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4530, average loss= 1.149505, average accuracy= 50.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 4540, average loss= 0.519425, average accuracy= 90.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 4550, average loss= 0.427683, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4560, average loss= 0.472807, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 4570, average loss= 1.092388, average accuracy= 40.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 4580, average loss= 0.363475, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4590, average loss= 0.961432, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4600, average loss= 0.627146, average accuracy= 90.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 4610, average loss= 0.919297, average accuracy= 70.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [had]
# Iter = 4620, average loss= 0.664102, average accuracy= 80.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 4630, average loss= 0.424035, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4640, average loss= 0.752380, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4650, average loss= 0.970721, average accuracy= 60.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 4660, average loss= 0.723756, average accuracy= 80.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4670, average loss= 0.774722, average accuracy= 70.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 4680, average loss= 0.338538, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4690, average loss= 0.943904, average accuracy= 70.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 4700, average loss= 0.373706, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 4710, average loss= 1.155722, average accuracy= 40.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4720, average loss= 0.328171, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4730, average loss= 0.342042, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4740, average loss= 0.380127, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4750, average loss= 0.958424, average accuracy= 60.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [.]
# Iter = 4760, average loss= 1.196976, average accuracy= 60.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 4770, average loss= 0.542688, average accuracy= 90.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 4780, average loss= 0.572607, average accuracy= 80.00%
# ['had', 'dinner', 'with'] - [Steve] vs [.]
# Iter = 4790, average loss= 0.409444, average accuracy= 90.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4800, average loss= 0.745915, average accuracy= 70.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4810, average loss= 1.297877, average accuracy= 40.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4820, average loss= 0.945164, average accuracy= 60.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 4830, average loss= 1.750810, average accuracy= 10.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [had]
# Iter = 4840, average loss= 1.133551, average accuracy= 50.00%
# ['had', 'breakfast', 'with'] - [David] vs [.]
# Iter = 4850, average loss= 1.449116, average accuracy= 40.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4860, average loss= 0.948473, average accuracy= 70.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 4870, average loss= 0.813693, average accuracy= 70.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4880, average loss= 1.443992, average accuracy= 40.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 4890, average loss= 1.127360, average accuracy= 50.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 4900, average loss= 1.233780, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 4910, average loss= 0.887547, average accuracy= 70.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 4920, average loss= 0.680354, average accuracy= 80.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 4930, average loss= 0.668620, average accuracy= 80.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 4940, average loss= 1.233591, average accuracy= 50.00%
# ['with', 'Steve', '.'] - [Steve] vs [.]
# Iter = 4950, average loss= 1.171368, average accuracy= 50.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Iter = 4960, average loss= 0.653668, average accuracy= 80.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4970, average loss= 0.670216, average accuracy= 80.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4980, average loss= 1.195569, average accuracy= 50.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 4990, average loss= 0.829470, average accuracy= 70.00%
# ['had', 'breakfast', 'with'] - [David] vs [Steve]
# Iter = 5000, average loss= 0.714285, average accuracy= 80.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [dinner]
# Optimization Finished!
# Elapsed time:  22.488377332687378 second(s)
# insert 3 words: Steve Had dinner
# cannot be found in dictionary
# insert 3 words: Steve had dinner
# Steve had dinner with Steve . . had
